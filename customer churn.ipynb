# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\mohib\appdata\local\programs\python\python39\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\mohib\appdata\roaming\python\python39\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mohib\appdata\local\programs\python\python39\lib\site-packages (from xgboost) (1.13.1)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

df = pd.read_csv("Customer-Churn-Records.csv")

# drop useless columns
df = df.drop(['RowNumber','CustomerId','Surname','Complain'], axis=1)

# encoding
df = pd.get_dummies(df, drop_first=True)

X = df.drop('Exited', axis=1)
y = df['Exited']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = XGBClassifier()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1595
#            1       0.66      0.48      0.56       405
#
#     accuracy                           0.84      2000
#    macro avg       0.77      0.71      0.73      2000
# weighted avg       0.83      0.84      0.84      2000

# %%
df.groupby('Complain')['Exited'].mean()
# Out:
# Complain
# 0    0.000503
# 1    0.995108
# Name: Exited, dtype: float64
